# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
DATA_DIR = '/home/iiticos/Desktop/Personal Docs/QC/IMC-Prosperity_2024/Data/round3/'

list = ['prices_round_3_day_2.csv','prices_round_3_day_1.csv','prices_round_3_day_0.csv']

df1 = pd.read_csv(DATA_DIR + list[0], sep=';')
df2 = pd.read_csv(DATA_DIR + list[1], sep=';')
df3 = pd.read_csv(DATA_DIR + list[2], sep=';')

# %%
df = pd.concat([df1, df3, df2], ignore_index=True)
df
# Out:
#         day  timestamp       product  bid_price_1  bid_volume_1  bid_price_2  \
# 0         2          0         ROSES        14421            27      14420.0
# 1         2          0  STRAWBERRIES         4036           255          NaN
# 2         2          0     CHOCOLATE         7888           123          NaN
# 3         2          0   GIFT_BASKET        70593             1      70592.0
# 4         2        100     CHOCOLATE         7889           102          NaN
# ...     ...        ...           ...          ...           ...          ...
# 119995    1     999800  STRAWBERRIES         4035           211          NaN
# 119996    1     999900         ROSES        14422            70          NaN
# 119997    1     999900  STRAWBERRIES         4035           204          NaN
# 119998    1     999900   GIFT_BASKET        70580            15      70579.0
# 119999    1     999900     CHOCOLATE         7887            44       7886.0
#
# ...

# %%
# df = df1

# %%
for i in ['ROSES','CHOCOLATE','STRAWBERRIES','GIFT_BASKET']:
    df_roses = df[df['product']==i]
    df_roses['mid_price'].plot()
    plt.title(i + ' Price')
    print("STD DEV : ", df_roses['mid_price'].std(), "MEAN : ", df_roses['mid_price'].mean())
    plt.show()
# Out:
# STD DEV :  161.4236902168419 MEAN :  14506.89705
# STD DEV :  99.34601701531568 MEAN :  7915.34725
# STD DEV :  27.40603199413994 MEAN :  4026.83735
# STD DEV :  600.0899600351073 MEAN :  70708.80063333333
